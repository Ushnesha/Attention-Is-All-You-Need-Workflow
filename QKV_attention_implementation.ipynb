# %%
# %pip install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: pandas==2.3.3 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: torch==2.3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: torchdata==0.8.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: torchtext==0.18.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: spacy==3.8.14 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (3.8.14)
# Requirement already satisfied: altair==6.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (6.0.0)
# Requirement already satisfied: jupytext==1.19.3 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.19.3)
# Requirement already satisfied: flake8==7.3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (7.3.0)
# Requirement already satisfied: black==26.5.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (26.5.1)
# Requirement already satisfied: GPUtil==1.4.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: wandb==0.27.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.27.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 3)) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torch==2.3.0->-r requirements.txt (line 4)) (2025.10.0)
# Requirement already satisfied: urllib3>=1.25 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torchdata==0.8.0->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torchdata==0.8.0->-r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from torchtext==0.18.0->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (0.20.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (2.12.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from spacy==3.8.14->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from altair==6.0.0->-r requirements.txt (line 8)) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from altair==6.0.0->-r requirements.txt (line 8)) (2.14.0)
# Requirement already satisfied: markdown-it-py>=1.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jupytext==1.19.3->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jupytext==1.19.3->-r requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: nbformat in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jupytext==1.19.3->-r requirements.txt (line 9)) (5.10.4)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jupytext==1.19.3->-r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from flake8==7.3.0->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from flake8==7.3.0->-r requirements.txt (line 10)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from flake8==7.3.0->-r requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from black==26.5.1->-r requirements.txt (line 11)) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from black==26.5.1->-r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from black==26.5.1->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: platformdirs>=2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from black==26.5.1->-r requirements.txt (line 11)) (4.9.2)
# Requirement already satisfied: pytokens~=0.4.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from black==26.5.1->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from wandb==0.27.2->-r requirements.txt (line 13)) (3.1.45)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from wandb==0.27.2->-r requirements.txt (line 13)) (6.33.1)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from wandb==0.27.2->-r requirements.txt (line 13)) (2.62.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from requests->torchdata==0.8.0->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from requests->torchdata==0.8.0->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from requests->torchdata==0.8.0->-r requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.12->spacy==3.8.14->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.8.14->-r requirements.txt (line 7)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.8.14->-r requirements.txt (line 7)) (14.2.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.27.2->-r requirements.txt (line 13)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.27.2->-r requirements.txt (line 13)) (5.0.2)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->-r requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->-r requirements.txt (line 8)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->-r requirements.txt (line 8)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->-r requirements.txt (line 8)) (0.29.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from markdown-it-py>=1.0->jupytext==1.19.3->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.3.3->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.8.14->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy==3.8.14->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from jinja2->torch==2.3.0->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from nbformat->jupytext==1.19.3->-r requirements.txt (line 9)) (2.21.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from nbformat->jupytext==1.19.3->-r requirements.txt (line 9)) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from nbformat->jupytext==1.19.3->-r requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/llm/lib/python3.11/site-packages (from sympy->torch==2.3.0->-r requirements.txt (line 4)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Implementing Scaled Dot-Product Attention: $softmax(\frac{QK^T}{\sqrt d_k})V$

# %%
import torch
import torch.nn.functional as F
import math
import plotly.graph_objects as go # For visualization
import numpy as np

# %%
def scaled_dot_product_attention(query, key, value, mask=None):
    """
    Computes Scaled Dot-Product Attention.

    Args:
        query: Query tensor; shape (batch_size, seq_len_q, d_k)
        key: Tensor; shape (batch_size, seq_len_k, d_k)
        value: Value tensor; shape (batch_size, seq_len_k, d_v)
               Note: seq_len_k must match between key and value.
               d_v (value dimension) can differ from d_k (query dimension).
        mask: Optional mask tensor; shape broadcastable to (batch_size, seq_len_q, seq_len_k).
              Positions with True or 1 indicate values to keep, False or 0 to mask out.

    Returns:
        output: The attention output tensor; shape (batch_size, seq_len_q, d_v)
        attention_weights: The attention weights; shape (batch_size, seq_len_q, seq_len_k)
    """

    #dimension of key
    d_k = key.size(-1)

    # 1. QK^T: (batch_size, seq_len_q, d_k) @ (batch_size, d_k, seq_len_k) -> (batch_size, seq_len_q, seq_len_k)
    scores = torch.matmul(query, key.transpose(-2,-1))

    # 2. Scale by sqrt(d_k)
    scaled_scores = scores / math.sqrt(d_k)

    # 3. Apply mask if provided
    # if mask position is 0, set the scaled_scores to -inf so that the softmax of it can be 0
    if mask is not None:
        scaled_scores = scaled_scores.masked_fill(mask == 0, -1e9)

    # 4. Softmax is applied on the last dimension (seq_len_k)
    attention_weights = F.softmax(scaled_scores, dim = -1)

    # Replace NaN with 0 to handle potential NaN from softmax if all scores in a row are -inf
    # This can happen if a query position is masked entirely against all keys.
    attention_weights = torch.nan_to_num(attention_weights)

    # 5. Multiply weights by V
    # (batch_size, seq_len_q, seq_len_k) @ (batch_size, seq_len_k, d_v) -> (batch_size, seq_len_q, d_v)
    outputs = torch.matmul(attention_weights, value)
    
    return outputs, attention_weights

# %% [markdown]
# #### Test code

# %%
batch_size = 1
seq_len_q = 3 # Sequence length for queries
seq_len_k = 4 # Sequence length for keys/values
d_k = 4      # Dimension of keys/queries
d_v = 4      # Dimension of values

# Generate random tensors
query = torch.randn(batch_size, seq_len_q, d_k)
key = torch.randn(batch_size, seq_len_k, d_k)
value = torch.randn(batch_size, seq_len_k, d_v)

# no mask
output, attention_weights = scaled_dot_product_attention(query, key, value)
print("--- Output without Mask ---")
print("Output shape:", output.shape) # Expected: [1, 3, 16]
print("Attention weights shape:", attention_weights.shape) # Expected: [1, 3, 4]
# Each row in attention_weights should sum to 1
print("Attention weights sum (second query):", attention_weights[0, 1, :].sum())

# with mask
# Create a sample mask. Let's mask out the last position for all queries.
# Mask shape: (batch_size, seq_len_q, seq_len_k)
# Here, simpler: (batch_size, 1, seq_len_k) broadcastable
mask = torch.ones(batch_size, 1, seq_len_k, dtype=torch.bool)
mask[:, :, -1] = 0 # Mask the last position (index 3)
# we mask it out for all query tokens and all attention heads at last position of each query

print("\nMask shape:", mask.shape)
print("Mask content:\n", mask)

output_masked, attention_weights_masked = scaled_dot_product_attention(query, key, value, mask=mask)

print("\n--- Output with Mask ---")
print("Output shape:", output_masked.shape) # Expected: [1, 3, 16]
print("Attention weights shape:", attention_weights_masked.shape) # Expected: [1, 3, 4]
print("Masked Attention weights (first query):\n", attention_weights_masked[0, 0, :])
# Note that the weight for the last position (index 3) should be 0 or very close to it.
print("Attention weights sum (first query, masked):", attention_weights_masked[0, 0, :].sum())
# Out:
# --- Output without Mask ---
# Output shape: torch.Size([1, 3, 4])
# Attention weights shape: torch.Size([1, 3, 4])
# Attention weights sum (second query): tensor(1.)
#
# Mask shape: torch.Size([1, 1, 4])
# Mask content:
#  tensor([[[ True,  True,  True, False]]])
#
# --- Output with Mask ---
# Output shape: torch.Size([1, 3, 4])
# Attention weights shape: torch.Size([1, 3, 4])
# Masked Attention weights (first query):
#  tensor([0.2531, 0.3115, 0.4354, 0.0000])
# Attention weights sum (first query, masked): tensor(1.)

# %%
print(query)
print(key.transpose(-2,-1))
scaled_scores = torch.matmul(query, key.transpose(-2,-1))/math.sqrt(d_k)
print(scaled_scores)
print(mask)
scaled_scores = scaled_scores.masked_fill(mask == 0, -1e9)
print(scaled_scores)
print(attention_weights)
print(value)
# Out:
# tensor([[[-0.8138,  0.3296, -0.5025,  0.1848],
#          [ 1.0168,  0.6117, -0.0758, -0.4085],
#          [ 0.4560,  1.4444, -1.5408,  0.3033]]])
# tensor([[[ 0.3261, -0.1516, -0.4483, -1.7781],
#          [ 0.0675,  0.4253,  0.4906,  0.9980],
#          [ 0.1454,  0.6355, -0.4122, -1.2583],
#          [-0.2452,  0.5926, -0.0556,  0.9023]]])
# tensor([[[-0.1807,  0.0269,  0.3617,  1.2875],
#          [ 0.2310, -0.0921, -0.0509, -0.7354],
#          [-0.0261, -0.1271,  0.5612,  1.4216]]])
# tensor([[[ True,  True,  True, False]]])
# tensor([[[-1.8072e-01,  2.6865e-02,  3.6167e-01, -1.0000e+09],
#          [ 2.3101e-01, -9.2090e-02, -5.0897e-02, -1.0000e+09],
#          [-2.6064e-02, -1.2714e-01,  5.6117e-01, -1.0000e+09]]])
# tensor([[[0.1206, 0.1484, 0.2074, 0.5235],
#          [0.3498, 0.2532, 0.2639, 0.1331],
#          [0.1257, 0.1136, 0.2261, 0.5346]]])
# tensor([[[ 0.1955, -0.5530, -0.5656, -1.6969],
#          [-0.7457, -0.3605, -2.5556,  0.3985],
#          [ 1.0412, -0.3374, -0.4750, -1.9724],
#          [ 0.0514, -0.7520,  1.1525,  1.1799]]])

# %%
# Use the attention_weights from the unmasked example
weights_np = attention_weights[0].detach().numpy() # Get weights for the first batch item

# Create heatmap data
fig_data = go.Heatmap(
    z=weights_np,
    x=[f'Pos {i}' for i in range(seq_len_k)],
    y=[f'Query Pos {i}' for i in range(seq_len_q)],
    colorscale='Blues', # Use blue color scale
    colorbar=dict(title='Attention Weight')
)

# Create layout
fig_layout = go.Layout(
    title='Attention Weights (Query vs Key)',
    xaxis_title="Sequence Position",
    yaxis_title="Query Sequence Position",
    yaxis_autorange='reversed', # Show query 0 at the top
    width=500, height=400, margin=dict(l=50, r=50, b=100, t=100, pad=4)
)

# Generate figure object as JSON for web display
fig = go.Figure(data=[fig_data], layout=fig_layout)
plotly_json = fig.to_json()

fig.show()
